# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | p
# Processing Record 2 of the Set 1 | s
# Processing Record 3 of the Set 1 | n
# Processing Record 4 of the Set 1 | s
# Processing Record 5 of the Set 1 | l
# Processing Record 6 of the Set 1 | i
# City not found. Skipping...
# Processing Record 7 of the Set 1 | c
# Processing Record 8 of the Set 1 | h
# Processing Record 9 of the Set 1 | g
# Processing Record 10 of the Set 1 | k
# Processing Record 11 of the Set 1 | s
# Processing Record 12 of the Set 1 | n
# Processing Record 13 of the Set 1 | v
# Processing Record 14 of the Set 1 | c
# Processing Record 15 of the Set 1 | t
# Processing Record 16 of the Set 1 | j
# Processing Record 17 of the Set 1 | h
# Processing Record 18 of the Set 1 | t
# Processing Record 19 of the Set 1 | p
# Processing Record 20 of the Set 1 | a
# Processing Record 21 of the Set 1 | p
# Processing Record 22 of the Set 1 | b
# Processing Record 23 of the Set 1 | r
# Processing Record 24 of the Set 1 | u
# Processing Record 25 of the Set 1 | b
# Processing Record 26 of the Set 1 | k
# Processing Record 27 of the Set 1 | u
# Processing Record 28 of the Set 1 | b
# Processing Record 29 of the Set 1 | e
# Processing Record 30 of the Set 1 | s
# Processing Record 31 of the Set 1 | s
# Processing Record 32 of the Set 1 | h
# Processing Record 33 of the Set 1 | c
# Processing Record 34 of the Set 1 | t
# Processing Record 35 of the Set 1 | t
# Processing Record 36 of the Set 1 | b
# Processing Record 37 of the Set 1 | b
# Processing Record 38 of the Set 1 | i
# Processing Record 39 of the Set 1 | p
# Processing Record 40 of the Set 1 | b
# Processing Record 41 of the Set 1 | a
# Processing Record 42 of the Set 1 | p
# Processing Record 43 of the Set 1 | t
# Processing Record 44 of the Set 1 | b
# Processing Record 45 of the Set 1 | s
# City not found. Skipping...
# Processing Record 46 of the Set 1 | a
# Processing Record 47 of the Set 1 | b
# Processing Record 48 of the Set 1 | s
# City not found. Skipping...
# Processing Record 49 of the Set 1 | p
# Processing Record 50 of the Set 1 | m
# Processing Record 1 of the Set 2 | k
# Processing Record 2 of the Set 2 | b
# City not found. Skipping...
# Processing Record 3 of the Set 2 | b
# City not found. Skipping...
# Processing Record 4 of the Set 2 | p
# Processing Record 5 of the Set 2 | y
# Processing Record 6 of the Set 2 | t
# City not found. Skipping...
# Processing Record 7 of the Set 2 | s
# Processing Record 8 of the Set 2 | b
# Processing Record 9 of the Set 2 | a
# Processing Record 10 of the Set 2 | k
# Processing Record 11 of the Set 2 | n
# Processing Record 12 of the Set 2 | h
# Processing Record 13 of the Set 2 | p
# Processing Record 14 of the Set 2 | m
# Processing Record 15 of the Set 2 | p
# Processing Record 16 of the Set 2 | l
# Processing Record 17 of the Set 2 | d
# Processing Record 18 of the Set 2 | p
# Processing Record 19 of the Set 2 | m
# City not found. Skipping...
# Processing Record 20 of the Set 2 | v
# Processing Record 21 of the Set 2 | b
# Processing Record 22 of the Set 2 | c
# Processing Record 23 of the Set 2 | c
# Processing Record 24 of the Set 2 | l
# Processing Record 25 of the Set 2 | p
# Processing Record 26 of the Set 2 | p
# Processing Record 27 of the Set 2 | n
# Processing Record 28 of the Set 2 | h
# Processing Record 29 of the Set 2 | z
# Processing Record 30 of the Set 2 | l
# Processing Record 31 of the Set 2 | m
# Processing Record 32 of the Set 2 | p
# Processing Record 33 of the Set 2 | t
# City not found. Skipping...
# Processing Record 34 of the Set 2 | p
# Processing Record 35 of the Set 2 | k
# Processing Record 36 of the Set 2 | d
# Processing Record 37 of the Set 2 | r
# Processing Record 38 of the Set 2 | i
# Processing Record 39 of the Set 2 | f
# Processing Record 40 of the Set 2 | t
# Processing Record 41 of the Set 2 | a
# Processing Record 42 of the Set 2 | t
# Processing Record 43 of the Set 2 | n
# Processing Record 44 of the Set 2 | b
# Processing Record 45 of the Set 2 | n
# Processing Record 46 of the Set 2 | s
# Processing Record 47 of the Set 2 | m
# Processing Record 48 of the Set 2 | s
# Processing Record 49 of the Set 2 | u
# Processing Record 50 of the Set 2 | d
# Processing Record 1 of the Set 3 | a
# City not found. Skipping...
# Processing Record 2 of the Set 3 | a
# Processing Record 3 of the Set 3 | s
# Processing Record 4 of the Set 3 | p
# Processing Record 5 of the Set 3 | b
# Processing Record 6 of the Set 3 | s
# Processing Record 7 of the Set 3 | p
# Processing Record 8 of the Set 3 | q
# Processing Record 9 of the Set 3 | n
# City not found. Skipping...
# Processing Record 10 of the Set 3 | s
# Processing Record 11 of the Set 3 | k
# Processing Record 12 of the Set 3 | f
# Processing Record 13 of the Set 3 | h
# Processing Record 14 of the Set 3 | k
# Processing Record 15 of the Set 3 | a
# Processing Record 16 of the Set 3 | l
# Processing Record 17 of the Set 3 | s
# Processing Record 18 of the Set 3 | r
# Processing Record 19 of the Set 3 | m
# Processing Record 20 of the Set 3 | a
# Processing Record 21 of the Set 3 | k
# Processing Record 22 of the Set 3 | b
# Processing Record 23 of the Set 3 | p
# Processing Record 24 of the Set 3 | b
# Processing Record 25 of the Set 3 | c
# Processing Record 26 of the Set 3 | b
# Processing Record 27 of the Set 3 | f
# Processing Record 28 of the Set 3 | t
# Processing Record 29 of the Set 3 | e
# Processing Record 30 of the Set 3 | m
# Processing Record 31 of the Set 3 | c
# Processing Record 32 of the Set 3 | t
# Processing Record 33 of the Set 3 | k
# Processing Record 34 of the Set 3 | c
# Processing Record 35 of the Set 3 | k
# Processing Record 36 of the Set 3 | m
# Processing Record 37 of the Set 3 | n
# Processing Record 38 of the Set 3 | m
# Processing Record 39 of the Set 3 | s
# Processing Record 40 of the Set 3 | r
# Processing Record 41 of the Set 3 | h
# Processing Record 42 of the Set 3 | k
# Processing Record 43 of the Set 3 | c
# Processing Record 44 of the Set 3 | m
# Processing Record 45 of the Set 3 | k
# Processing Record 46 of the Set 3 | s
# Processing Record 47 of the Set 3 | s
# Processing Record 48 of the Set 3 | m
# Processing Record 49 of the Set 3 | a
# Processing Record 50 of the Set 3 | h
# Processing Record 1 of the Set 4 | b
# Processing Record 2 of the Set 4 | l
# Processing Record 3 of the Set 4 | b
# Processing Record 4 of the Set 4 | e
# Processing Record 5 of the Set 4 | h
# Processing Record 6 of the Set 4 | c
# Processing Record 7 of the Set 4 | b
# Processing Record 8 of the Set 4 | g
# Processing Record 9 of the Set 4 | m
# Processing Record 10 of the Set 4 | t
# Processing Record 11 of the Set 4 | r
# Processing Record 12 of the Set 4 | k
# Processing Record 13 of the Set 4 | r
# Processing Record 14 of the Set 4 | i
# Processing Record 15 of the Set 4 | t
# Processing Record 16 of the Set 4 | s
# Processing Record 17 of the Set 4 | l
# Processing Record 18 of the Set 4 | d
# Processing Record 19 of the Set 4 | v
# Processing Record 20 of the Set 4 | c
# Processing Record 21 of the Set 4 | l
# Processing Record 22 of the Set 4 | c
# Processing Record 23 of the Set 4 | f
# Processing Record 24 of the Set 4 | s
# Processing Record 25 of the Set 4 | v
# Processing Record 26 of the Set 4 | s
# Processing Record 27 of the Set 4 | n
# Processing Record 28 of the Set 4 | u
# Processing Record 29 of the Set 4 | b
# City not found. Skipping...
# Processing Record 30 of the Set 4 | r
# Processing Record 31 of the Set 4 | g
# Processing Record 32 of the Set 4 | s
# Processing Record 33 of the Set 4 | m
# Processing Record 34 of the Set 4 | d
# Processing Record 35 of the Set 4 | b
# Processing Record 36 of the Set 4 | i
# Processing Record 37 of the Set 4 | u
# Processing Record 38 of the Set 4 | s
# City not found. Skipping...
# Processing Record 39 of the Set 4 | b
# Processing Record 40 of the Set 4 | l
# Processing Record 41 of the Set 4 | b
# Processing Record 42 of the Set 4 | c
# Processing Record 43 of the Set 4 | s
# Processing Record 44 of the Set 4 | c
# Processing Record 45 of the Set 4 | t
# Processing Record 46 of the Set 4 | s
# City not found. Skipping...
# Processing Record 47 of the Set 4 | r
# Processing Record 48 of the Set 4 | b
# Processing Record 49 of the Set 4 | s
# Processing Record 50 of the Set 4 | s
# Processing Record 1 of the Set 5 | r
# Processing Record 2 of the Set 5 | n
# Processing Record 3 of the Set 5 | k
# Processing Record 4 of the Set 5 | h
# Processing Record 5 of the Set 5 | t
# City not found. Skipping...
# Processing Record 6 of the Set 5 | f
# Processing Record 7 of the Set 5 | p
# Processing Record 8 of the Set 5 | v
# Processing Record 9 of the Set 5 | b
# Processing Record 10 of the Set 5 | o
# Processing Record 11 of the Set 5 | b
# Processing Record 12 of the Set 5 | y
# City not found. Skipping...
# Processing Record 13 of the Set 5 | v
# Processing Record 14 of the Set 5 | h
# Processing Record 15 of the Set 5 | p
# Processing Record 16 of the Set 5 | s
# Processing Record 17 of the Set 5 | a
# Processing Record 18 of the Set 5 | q
# Processing Record 19 of the Set 5 | h
# Processing Record 20 of the Set 5 | o
# Processing Record 21 of the Set 5 | l
# Processing Record 22 of the Set 5 | s
# Processing Record 23 of the Set 5 | p
# Processing Record 24 of the Set 5 | n
# Processing Record 25 of the Set 5 | n
# Processing Record 26 of the Set 5 | l
# Processing Record 27 of the Set 5 | l
# Processing Record 28 of the Set 5 | v
# Processing Record 29 of the Set 5 | c
# Processing Record 30 of the Set 5 | h
# Processing Record 31 of the Set 5 | l
# Processing Record 32 of the Set 5 | b
# Processing Record 33 of the Set 5 | a
# Processing Record 34 of the Set 5 | y
# Processing Record 35 of the Set 5 | p
# Processing Record 36 of the Set 5 | h
# City not found. Skipping...
# Processing Record 37 of the Set 5 | h
# Processing Record 38 of the Set 5 | m
# Processing Record 39 of the Set 5 | a
# Processing Record 40 of the Set 5 | g
# Processing Record 41 of the Set 5 | s
# Processing Record 42 of the Set 5 | t
# Processing Record 43 of the Set 5 | n
# Processing Record 44 of the Set 5 | a
# Processing Record 45 of the Set 5 | b
# Processing Record 46 of the Set 5 | d
# Processing Record 47 of the Set 5 | t
# City not found. Skipping...
# Processing Record 48 of the Set 5 | s
# Processing Record 49 of the Set 5 | l
# Processing Record 50 of the Set 5 | d
# City not found. Skipping...
# Processing Record 1 of the Set 6 | b
# Processing Record 2 of the Set 6 | u
# Processing Record 3 of the Set 6 | b
# Processing Record 4 of the Set 6 | l
# Processing Record 5 of the Set 6 | a
# City not found. Skipping...
# Processing Record 6 of the Set 6 | o
# Processing Record 7 of the Set 6 | f
# Processing Record 8 of the Set 6 | l
# Processing Record 9 of the Set 6 | s
# City not found. Skipping...
# Processing Record 10 of the Set 6 | e
# Processing Record 11 of the Set 6 | c
# Processing Record 12 of the Set 6 | w
# Processing Record 13 of the Set 6 | m
# Processing Record 14 of the Set 6 | a
# Processing Record 15 of the Set 6 | b
# Processing Record 16 of the Set 6 | p
# Processing Record 17 of the Set 6 | q
# Processing Record 18 of the Set 6 | b
# Processing Record 19 of the Set 6 | d
# Processing Record 20 of the Set 6 | s
# Processing Record 21 of the Set 6 | l
# Processing Record 22 of the Set 6 | s
# Processing Record 23 of the Set 6 | k
# Processing Record 24 of the Set 6 | g
# Processing Record 25 of the Set 6 | v
# Processing Record 26 of the Set 6 | n
# Processing Record 27 of the Set 6 | t
# Processing Record 28 of the Set 6 | h
# City not found. Skipping...
# Processing Record 29 of the Set 6 | c
# Processing Record 30 of the Set 6 | d
# Processing Record 31 of the Set 6 | n
# Processing Record 32 of the Set 6 | b
# Processing Record 33 of the Set 6 | k
# Processing Record 34 of the Set 6 | n
# Processing Record 35 of the Set 6 | e
# Processing Record 36 of the Set 6 | g
# Processing Record 37 of the Set 6 | k
# Processing Record 38 of the Set 6 | e
# Processing Record 39 of the Set 6 | t
# Processing Record 40 of the Set 6 | g
# City not found. Skipping...
# Processing Record 41 of the Set 6 | m
# Processing Record 42 of the Set 6 | m
# Processing Record 43 of the Set 6 | s
# Processing Record 44 of the Set 6 | k
# Processing Record 45 of the Set 6 | d
# Processing Record 46 of the Set 6 | p
# Processing Record 47 of the Set 6 | y
# Processing Record 48 of the Set 6 | b
# City not found. Skipping...
# Processing Record 49 of the Set 6 | n
# Processing Record 50 of the Set 6 | a
# Processing Record 1 of the Set 7 | t
# City not found. Skipping...
# Processing Record 2 of the Set 7 | t
# Processing Record 3 of the Set 7 | s
# City not found. Skipping...
# Processing Record 4 of the Set 7 | c
# Processing Record 5 of the Set 7 | i
# Processing Record 6 of the Set 7 | f
# Processing Record 7 of the Set 7 | h
# Processing Record 8 of the Set 7 | p
# Processing Record 9 of the Set 7 | d
# Processing Record 10 of the Set 7 | h
# Processing Record 11 of the Set 7 | l
# Processing Record 12 of the Set 7 | g
# Processing Record 13 of the Set 7 | s
# Processing Record 14 of the Set 7 | p
# Processing Record 15 of the Set 7 | s
# Processing Record 16 of the Set 7 | b
# Processing Record 17 of the Set 7 | s
# Processing Record 18 of the Set 7 | m
# Processing Record 19 of the Set 7 | c
# Processing Record 20 of the Set 7 | k
# Processing Record 21 of the Set 7 | p
# Processing Record 22 of the Set 7 | m
# Processing Record 23 of the Set 7 | s
# Processing Record 24 of the Set 7 | s
# Processing Record 25 of the Set 7 | n
# Processing Record 26 of the Set 7 | s
# Processing Record 27 of the Set 7 | s
# Processing Record 28 of the Set 7 | h
# Processing Record 29 of the Set 7 | p
# Processing Record 30 of the Set 7 | u
# Processing Record 31 of the Set 7 | h
# Processing Record 32 of the Set 7 | m
# Processing Record 33 of the Set 7 | s
# Processing Record 34 of the Set 7 | p
# Processing Record 35 of the Set 7 | c
# Processing Record 36 of the Set 7 | a
# Processing Record 37 of the Set 7 | c
# Processing Record 38 of the Set 7 | l
# Processing Record 39 of the Set 7 | s
# Processing Record 40 of the Set 7 | t
# Processing Record 41 of the Set 7 | b
# Processing Record 42 of the Set 7 | j
# Processing Record 43 of the Set 7 | g
# Processing Record 44 of the Set 7 | v
# Processing Record 45 of the Set 7 | k
# Processing Record 46 of the Set 7 | a
# City not found. Skipping...
# Processing Record 47 of the Set 7 | m
# Processing Record 48 of the Set 7 | m
# Processing Record 49 of the Set 7 | k
# Processing Record 50 of the Set 7 | c
# Processing Record 1 of the Set 8 | a
# Processing Record 2 of the Set 8 | c
# Processing Record 3 of the Set 8 | t
# Processing Record 4 of the Set 8 | n
# Processing Record 5 of the Set 8 | g
# City not found. Skipping...
# Processing Record 6 of the Set 8 | n
# Processing Record 7 of the Set 8 | a
# Processing Record 8 of the Set 8 | b
# Processing Record 9 of the Set 8 | g
# Processing Record 10 of the Set 8 | b
# Processing Record 11 of the Set 8 | b
# City not found. Skipping...
# Processing Record 12 of the Set 8 | g
# City not found. Skipping...
# Processing Record 13 of the Set 8 | t
# Processing Record 14 of the Set 8 | s
# Processing Record 15 of the Set 8 | u
# Processing Record 16 of the Set 8 | s
# Processing Record 17 of the Set 8 | b
# Processing Record 18 of the Set 8 | c
# Processing Record 19 of the Set 8 | s
# Processing Record 20 of the Set 8 | m
# Processing Record 21 of the Set 8 | w
# Processing Record 22 of the Set 8 | b
# Processing Record 23 of the Set 8 | p
# Processing Record 24 of the Set 8 | o
# Processing Record 25 of the Set 8 | k
# Processing Record 26 of the Set 8 | c
# Processing Record 27 of the Set 8 | o
# Processing Record 28 of the Set 8 | x
# Processing Record 29 of the Set 8 | k
# Processing Record 30 of the Set 8 | t
# City not found. Skipping...
# Processing Record 31 of the Set 8 | b
# Processing Record 32 of the Set 8 | b
# Processing Record 33 of the Set 8 | k
# Processing Record 34 of the Set 8 | l
# Processing Record 35 of the Set 8 | l
# Processing Record 36 of the Set 8 | r
# Processing Record 37 of the Set 8 | m
# City not found. Skipping...
# Processing Record 38 of the Set 8 | m
# Processing Record 39 of the Set 8 | s
# Processing Record 40 of the Set 8 | a
# Processing Record 41 of the Set 8 | g
# Processing Record 42 of the Set 8 | k
# Processing Record 43 of the Set 8 | p
# Processing Record 44 of the Set 8 | l
# Processing Record 45 of the Set 8 | c
# Processing Record 46 of the Set 8 | t
# Processing Record 47 of the Set 8 | b
# Processing Record 48 of the Set 8 | k
# Processing Record 49 of the Set 8 | k
# Processing Record 50 of the Set 8 | a
# Processing Record 1 of the Set 9 | b
# Processing Record 2 of the Set 9 | g
# Processing Record 3 of the Set 9 | z
# Processing Record 4 of the Set 9 | a
# Processing Record 5 of the Set 9 | v
# Processing Record 6 of the Set 9 | a
# Processing Record 7 of the Set 9 | n
# Processing Record 8 of the Set 9 | z
# Processing Record 9 of the Set 9 | a
# Processing Record 10 of the Set 9 | p
# Processing Record 11 of the Set 9 | b
# Processing Record 12 of the Set 9 | v
# City not found. Skipping...
# Processing Record 13 of the Set 9 | l
# Processing Record 14 of the Set 9 | f
# Processing Record 15 of the Set 9 | s
# Processing Record 16 of the Set 9 | z
# City not found. Skipping...
# Processing Record 17 of the Set 9 | y
# Processing Record 18 of the Set 9 | p
# Processing Record 19 of the Set 9 | w
# Processing Record 20 of the Set 9 | k
# City not found. Skipping...
# Processing Record 21 of the Set 9 | h
# Processing Record 22 of the Set 9 | r
# Processing Record 23 of the Set 9 | b
# Processing Record 24 of the Set 9 | i
# Processing Record 25 of the Set 9 | s
# Processing Record 26 of the Set 9 | k
# Processing Record 27 of the Set 9 | y
# Processing Record 28 of the Set 9 | i
# Processing Record 29 of the Set 9 | m
# Processing Record 30 of the Set 9 | v
# Processing Record 31 of the Set 9 | p
# Processing Record 32 of the Set 9 | n
# Processing Record 33 of the Set 9 | i
# Processing Record 34 of the Set 9 | d
# Processing Record 35 of the Set 9 | p
# Processing Record 36 of the Set 9 | d
# Processing Record 37 of the Set 9 | b
# Processing Record 38 of the Set 9 | b
# Processing Record 39 of the Set 9 | n
# City not found. Skipping...
# Processing Record 40 of the Set 9 | f
# Processing Record 41 of the Set 9 | t
# Processing Record 42 of the Set 9 | n
# Processing Record 43 of the Set 9 | d
# Processing Record 44 of the Set 9 | k
# Processing Record 45 of the Set 9 | k
# Processing Record 46 of the Set 9 | c
# Processing Record 47 of the Set 9 | h
# Processing Record 48 of the Set 9 | r
# Processing Record 49 of the Set 9 | t
# Processing Record 50 of the Set 9 | c
# Processing Record 1 of the Set 10 | f
# Processing Record 2 of the Set 10 | s
# Processing Record 3 of the Set 10 | s
# Processing Record 4 of the Set 10 | j
# Processing Record 5 of the Set 10 | c
# Processing Record 6 of the Set 10 | l
# City not found. Skipping...
# Processing Record 7 of the Set 10 | c
# Processing Record 8 of the Set 10 | n
# Processing Record 9 of the Set 10 | m
# Processing Record 10 of the Set 10 | c
# Processing Record 11 of the Set 10 | j
# Processing Record 12 of the Set 10 | c
# Processing Record 13 of the Set 10 | w
# Processing Record 14 of the Set 10 | a
# Processing Record 15 of the Set 10 | c
# Processing Record 16 of the Set 10 | s
# Processing Record 17 of the Set 10 | j
# Processing Record 18 of the Set 10 | v
# Processing Record 19 of the Set 10 | j
# Processing Record 20 of the Set 10 | r
# Processing Record 21 of the Set 10 | m
# Processing Record 22 of the Set 10 | j
# Processing Record 23 of the Set 10 | n
# Processing Record 24 of the Set 10 | m
# Processing Record 25 of the Set 10 | o
# Processing Record 26 of the Set 10 | b
# Processing Record 27 of the Set 10 | c
# Processing Record 28 of the Set 10 | o
# Processing Record 29 of the Set 10 | k
# Processing Record 30 of the Set 10 | n
# Processing Record 31 of the Set 10 | p
# Processing Record 32 of the Set 10 | k
# Processing Record 33 of the Set 10 | c
# Processing Record 34 of the Set 10 | l
# Processing Record 35 of the Set 10 | n
# Processing Record 36 of the Set 10 | w
# Processing Record 37 of the Set 10 | d
# Processing Record 38 of the Set 10 | s
# City not found. Skipping...
# Processing Record 39 of the Set 10 | h
# Processing Record 40 of the Set 10 | w
# City not found. Skipping...
# Processing Record 41 of the Set 10 | v
# Processing Record 42 of the Set 10 | a
# Processing Record 43 of the Set 10 | w
# Processing Record 44 of the Set 10 | c
# Processing Record 45 of the Set 10 | t
# Processing Record 46 of the Set 10 | g
# Processing Record 47 of the Set 10 | b
# Processing Record 48 of the Set 10 | m
# Processing Record 49 of the Set 10 | n
# Processing Record 50 of the Set 10 | c
# Processing Record 1 of the Set 11 | b
# Processing Record 2 of the Set 11 | b
# Processing Record 3 of the Set 11 | t
# Processing Record 4 of the Set 11 | u
# Processing Record 5 of the Set 11 | s
# Processing Record 6 of the Set 11 | r
# City not found. Skipping...
# Processing Record 7 of the Set 11 | m
# City not found. Skipping...
# Processing Record 8 of the Set 11 | s
# Processing Record 9 of the Set 11 | p
# City not found. Skipping...
# Processing Record 10 of the Set 11 | x
# Processing Record 11 of the Set 11 | s
# Processing Record 12 of the Set 11 | s
# Processing Record 13 of the Set 11 | e
# Processing Record 14 of the Set 11 | g
# Processing Record 15 of the Set 11 | h
# Processing Record 16 of the Set 11 | k
# Processing Record 17 of the Set 11 | n
# Processing Record 18 of the Set 11 | z
# Processing Record 19 of the Set 11 | g
# Processing Record 20 of the Set 11 | j
# Processing Record 21 of the Set 11 | p
# Processing Record 22 of the Set 11 | m
# Processing Record 23 of the Set 11 | l
# Processing Record 24 of the Set 11 | s
# Processing Record 25 of the Set 11 | m
# Processing Record 26 of the Set 11 | d
# Processing Record 27 of the Set 11 | a
# City not found. Skipping...
# Processing Record 28 of the Set 11 | s
# Processing Record 29 of the Set 11 | l
# Processing Record 30 of the Set 11 | s
# City not found. Skipping...
# Processing Record 31 of the Set 11 | m
# Processing Record 32 of the Set 11 | o
# Processing Record 33 of the Set 11 | m
# City not found. Skipping...
# Processing Record 34 of the Set 11 | s
# Processing Record 35 of the Set 11 | a
# Processing Record 36 of the Set 11 | y
# Processing Record 37 of the Set 11 | d
# Processing Record 38 of the Set 11 | b
# Processing Record 39 of the Set 11 | b
# Processing Record 40 of the Set 11 | k
# Processing Record 41 of the Set 11 | m
# Processing Record 42 of the Set 11 | n
# Processing Record 43 of the Set 11 | j
# City not found. Skipping...
# Processing Record 44 of the Set 11 | p
# Processing Record 45 of the Set 11 | n
# Processing Record 46 of the Set 11 | p
# Processing Record 47 of the Set 11 | m
# Processing Record 48 of the Set 11 | p
# Processing Record 49 of the Set 11 | s
# Processing Record 50 of the Set 11 | a
# Processing Record 1 of the Set 12 | d
# Processing Record 2 of the Set 12 | b
# Processing Record 3 of the Set 12 | i
# Processing Record 4 of the Set 12 | a
# Processing Record 5 of the Set 12 | p
# Processing Record 6 of the Set 12 | n
# Processing Record 7 of the Set 12 | p
# Processing Record 8 of the Set 12 | m
# Processing Record 9 of the Set 12 | c
# Processing Record 10 of the Set 12 | e
# Processing Record 11 of the Set 12 | k
# Processing Record 12 of the Set 12 | q
# Processing Record 13 of the Set 12 | p
# Processing Record 14 of the Set 12 | k
# Processing Record 15 of the Set 12 | r
# Processing Record 16 of the Set 12 | t
# Processing Record 17 of the Set 12 | l
# Processing Record 18 of the Set 12 | t
# City not found. Skipping...
# Processing Record 19 of the Set 12 | t
# Processing Record 20 of the Set 12 | k
# Processing Record 21 of the Set 12 | c
# Processing Record 22 of the Set 12 | h
# Processing Record 23 of the Set 12 | m
# Processing Record 24 of the Set 12 | p
# Processing Record 25 of the Set 12 | h
# Processing Record 26 of the Set 12 | j
# Processing Record 27 of the Set 12 | k
# Processing Record 28 of the Set 12 | z
# Processing Record 29 of the Set 12 | d
# City not found. Skipping...
# Processing Record 30 of the Set 12 | h
# Processing Record 31 of the Set 12 | u
# City not found. Skipping...
# Processing Record 32 of the Set 12 | k
# Processing Record 33 of the Set 12 | o
# Processing Record 34 of the Set 12 | n
# Processing Record 35 of the Set 12 | d
# City not found. Skipping...
# Processing Record 36 of the Set 12 | h
# Processing Record 37 of the Set 12 | r
# Processing Record 38 of the Set 12 | m
# Processing Record 39 of the Set 12 | d
# Processing Record 40 of the Set 12 | t
# Processing Record 41 of the Set 12 | l
# Processing Record 42 of the Set 12 | p
# Processing Record 43 of the Set 12 | g
# Processing Record 44 of the Set 12 | b
# Processing Record 45 of the Set 12 | s
# Processing Record 46 of the Set 12 | b
# Processing Record 47 of the Set 12 | m
# Processing Record 48 of the Set 12 | u
# Processing Record 49 of the Set 12 | e
# Processing Record 50 of the Set 12 | n
# Processing Record 1 of the Set 13 | b
# Processing Record 2 of the Set 13 | v
# Processing Record 3 of the Set 13 | c
# Processing Record 4 of the Set 13 | y
# Processing Record 5 of the Set 13 | y
# Processing Record 6 of the Set 13 | j
# Processing Record 7 of the Set 13 | m
# Processing Record 8 of the Set 13 | f
# Processing Record 9 of the Set 13 | j
# City not found. Skipping...
# Processing Record 10 of the Set 13 | d
# Processing Record 11 of the Set 13 | a
# Processing Record 12 of the Set 13 | b
# City not found. Skipping...
# Processing Record 13 of the Set 13 | k
# Processing Record 14 of the Set 13 | g
# Processing Record 15 of the Set 13 | b
# Processing Record 16 of the Set 13 | c
# Processing Record 17 of the Set 13 | o
# Processing Record 18 of the Set 13 | d
# Processing Record 19 of the Set 13 | t
# Processing Record 20 of the Set 13 | l
# Processing Record 21 of the Set 13 | m
# Processing Record 22 of the Set 13 | l
# City not found. Skipping...
# Processing Record 23 of the Set 13 | y
# Processing Record 24 of the Set 13 | s
# Processing Record 25 of the Set 13 | g
# City not found. Skipping...
# Processing Record 26 of the Set 13 | n
# Processing Record 27 of the Set 13 | q
# Processing Record 28 of the Set 13 | a
# Processing Record 29 of the Set 13 | b
# Processing Record 30 of the Set 13 | p
# Processing Record 31 of the Set 13 | n
# Processing Record 32 of the Set 13 | p
# Processing Record 33 of the Set 13 | a
# Processing Record 34 of the Set 13 | s
# Processing Record 35 of the Set 13 | r
# City not found. Skipping...
# Processing Record 36 of the Set 13 | k
# Processing Record 37 of the Set 13 | v
# Processing Record 38 of the Set 13 | k
# Processing Record 39 of the Set 13 | i
# Processing Record 40 of the Set 13 | i
# Processing Record 41 of the Set 13 | s
# Processing Record 42 of the Set 13 | m
# City not found. Skipping...
# Processing Record 43 of the Set 13 | a
# City not found. Skipping...
# Processing Record 44 of the Set 13 | d
# Processing Record 45 of the Set 13 | h
# Processing Record 46 of the Set 13 | k
# Processing Record 47 of the Set 13 | b
# Processing Record 48 of the Set 13 | s
# Processing Record 49 of the Set 13 | b
# City not found. Skipping...
# Processing Record 50 of the Set 13 | e
# Processing Record 1 of the Set 14 | a
# Processing Record 2 of the Set 14 | m
# Processing Record 3 of the Set 14 | m
# Processing Record 4 of the Set 14 | l
# Processing Record 5 of the Set 14 | v
# Processing Record 6 of the Set 14 | b
# City not found. Skipping...
# Processing Record 7 of the Set 14 | c
# Processing Record 8 of the Set 14 | a
# Processing Record 9 of the Set 14 | g
# Processing Record 10 of the Set 14 | h
# Processing Record 11 of the Set 14 | k
# Processing Record 12 of the Set 14 | b
# Processing Record 13 of the Set 14 | v
# Processing Record 14 of the Set 14 | m
# Processing Record 15 of the Set 14 | t
# Processing Record 16 of the Set 14 | r
# Processing Record 17 of the Set 14 | a
# Processing Record 18 of the Set 14 | c
# Processing Record 19 of the Set 14 | s
# Processing Record 20 of the Set 14 | r
# Processing Record 21 of the Set 14 | h
# Processing Record 22 of the Set 14 | n
# Processing Record 23 of the Set 14 | b
# Processing Record 24 of the Set 14 | s
# Processing Record 25 of the Set 14 | s
# Processing Record 26 of the Set 14 | c
# Processing Record 27 of the Set 14 | m
# Processing Record 28 of the Set 14 | g
# Processing Record 29 of the Set 14 | g
# Processing Record 30 of the Set 14 | v
# Processing Record 31 of the Set 14 | c
# Processing Record 32 of the Set 14 | s
# Processing Record 33 of the Set 14 | l
# Processing Record 34 of the Set 14 | f
# Processing Record 35 of the Set 14 | a
# Processing Record 36 of the Set 14 | h
# Processing Record 37 of the Set 14 | s
# Processing Record 38 of the Set 14 | i
# Processing Record 39 of the Set 14 | e
# Processing Record 40 of the Set 14 | a
# Processing Record 41 of the Set 14 | v
# Processing Record 42 of the Set 14 | n
# Processing Record 43 of the Set 14 | m
# Processing Record 44 of the Set 14 | k
# Processing Record 45 of the Set 14 | m
# Processing Record 46 of the Set 14 | s
# Processing Record 47 of the Set 14 | e
# Processing Record 48 of the Set 14 | e
# Processing Record 49 of the Set 14 | s
# Processing Record 50 of the Set 14 | s
# Processing Record 1 of the Set 15 | a
# Processing Record 2 of the Set 15 | m
# Processing Record 3 of the Set 15 | a
# City not found. Skipping...
# Processing Record 4 of the Set 15 | c
# Processing Record 5 of the Set 15 | s
# Processing Record 6 of the Set 15 | m
# Processing Record 7 of the Set 15 | v
# Processing Record 8 of the Set 15 | i
# Processing Record 9 of the Set 15 | z
# Processing Record 10 of the Set 15 | i
# Processing Record 11 of the Set 15 | o
# Processing Record 12 of the Set 15 | m
# Processing Record 13 of the Set 15 | m
# Processing Record 14 of the Set 15 | m
# Processing Record 15 of the Set 15 | s
# City not found. Skipping...
# Processing Record 16 of the Set 15 | i
# Processing Record 17 of the Set 15 | c
# Processing Record 18 of the Set 15 | m
# Processing Record 19 of the Set 15 | u
# City not found. Skipping...
# Processing Record 20 of the Set 15 | k
# Processing Record 21 of the Set 15 | a
# Processing Record 22 of the Set 15 | n
# Processing Record 23 of the Set 15 | s
# Processing Record 24 of the Set 15 | s
# Processing Record 25 of the Set 15 | b
# Processing Record 26 of the Set 15 | b
# Processing Record 27 of the Set 15 | h
# Processing Record 28 of the Set 15 | t
# Processing Record 29 of the Set 15 | b
# Processing Record 30 of the Set 15 | m
# Processing Record 31 of the Set 15 | p
# Processing Record 32 of the Set 15 | a
# Processing Record 33 of the Set 15 | c
# Processing Record 34 of the Set 15 | h
# Processing Record 35 of the Set 15 | b
# Processing Record 36 of the Set 15 | c
# Processing Record 37 of the Set 15 | n
# Processing Record 38 of the Set 15 | m
# Processing Record 39 of the Set 15 | g
# Processing Record 40 of the Set 15 | s
# Processing Record 41 of the Set 15 | u
# Processing Record 42 of the Set 15 | u
# City not found. Skipping...
# Processing Record 43 of the Set 15 | s
# Processing Record 44 of the Set 15 | k
# Processing Record 45 of the Set 15 | r
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 683

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#   City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    P      CA  50.6996 -127.4199     41.18        93         100        6.91
# 1    S      RU  52.9167   54.7500     29.12        97         100       14.00
# 2    N      RU  56.6709  124.6491    -10.34        97         100        6.89
# 3    S      ZA -33.0117   17.9442     77.05        87          62       18.03
# 4    L      ZM -17.8419   25.8543     66.94        97         100        3.76
#
#   Current Description
# 0          light rain
# 1          light snow
# 2     overcast clouds
# 3       broken clouds
# 4     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
