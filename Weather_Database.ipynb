# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c712c97553a3b93490ce4a9697ca3e3

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | karratha
# Processing Record 2 of the Set 1 | oussouye
# Processing Record 3 of the Set 1 | punta arenas
# Processing Record 4 of the Set 1 | narsaq
# Processing Record 5 of the Set 1 | geraldton
# Processing Record 6 of the Set 1 | busselton
# Processing Record 7 of the Set 1 | kloulklubed
# Processing Record 8 of the Set 1 | bredasdorp
# Processing Record 9 of the Set 1 | palmar
# Processing Record 10 of the Set 1 | san policarpo
# Processing Record 11 of the Set 1 | rikitea
# Processing Record 12 of the Set 1 | mataura
# Processing Record 13 of the Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of the Set 1 | georgetown
# Processing Record 15 of the Set 1 | vaini
# Processing Record 16 of the Set 1 | airai
# Processing Record 17 of the Set 1 | roebourne
# Processing Record 18 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of the Set 1 | grindavik
# Processing Record 20 of the Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of the Set 1 | carballo
# Processing Record 22 of the Set 1 | bayji
# Processing Record 23 of the Set 1 | avarua
# Processing Record 24 of the Set 1 | tuktoyaktuk
# Processing Record 25 of the Set 1 | butaritari
# Processing Record 26 of the Set 1 | monteagudo
# Processing Record 27 of the Set 1 | upernavik
# Processing Record 28 of the Set 1 | hithadhoo
# Processing Record 29 of the Set 1 | zhuhai
# Processing Record 30 of the Set 1 | cape town
# Processing Record 31 of the Set 1 | haines junction
# Processing Record 32 of the Set 1 | guanagazapa
# Processing Record 33 of the Set 1 | east london
# Processing Record 34 of the Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of the Set 1 | simpang
# Processing Record 36 of the Set 1 | lompoc
# Processing Record 37 of the Set 1 | hobart
# Processing Record 38 of the Set 1 | charters towers
# Processing Record 39 of the Set 1 | sokoto
# Processing Record 40 of the Set 1 | san patricio
# Processing Record 41 of the Set 1 | hermanus
# Processing Record 42 of the Set 1 | beringovskiy
# Processing Record 43 of the Set 1 | najran
# Processing Record 44 of the Set 1 | zhigansk
# Processing Record 45 of the Set 1 | clyde river
# Processing Record 46 of the Set 1 | syedove
# Processing Record 47 of the Set 1 | opuwo
# Processing Record 48 of the Set 1 | paracuru
# Processing Record 49 of the Set 1 | qinhuangdao
# Processing Record 50 of the Set 1 | tena
# Processing Record 1 of the Set 2 | saint-philippe
# Processing Record 2 of the Set 2 | vao
# Processing Record 3 of the Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 4 of the Set 2 | pandharpur
# Processing Record 5 of the Set 2 | kathu
# Processing Record 6 of the Set 2 | alofi
# Processing Record 7 of the Set 2 | yellowknife
# Processing Record 8 of the Set 2 | lagoa
# Processing Record 9 of the Set 2 | kapaa
# Processing Record 10 of the Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of the Set 2 | nikolskoye
# Processing Record 12 of the Set 2 | husavik
# Processing Record 13 of the Set 2 | bethel
# Processing Record 14 of the Set 2 | ushuaia
# Processing Record 15 of the Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 16 of the Set 2 | comachuen
# Processing Record 17 of the Set 2 | port hardy
# Processing Record 18 of the Set 2 | horsham
# Processing Record 19 of the Set 2 | cayenne
# Processing Record 20 of the Set 2 | waingapu
# Processing Record 21 of the Set 2 | atuona
# Processing Record 22 of the Set 2 | port elizabeth
# Processing Record 23 of the Set 2 | dabakala
# Processing Record 24 of the Set 2 | hilo
# Processing Record 25 of the Set 2 | lakki marwat
# Processing Record 26 of the Set 2 | albany
# Processing Record 27 of the Set 2 | mahebourg
# Processing Record 28 of the Set 2 | leningradskiy
# Processing Record 29 of the Set 2 | pacific grove
# Processing Record 30 of the Set 2 | jamestown
# Processing Record 31 of the Set 2 | pangnirtung
# Processing Record 32 of the Set 2 | carnarvon
# Processing Record 33 of the Set 2 | finschhafen
# Processing Record 34 of the Set 2 | port alfred
# Processing Record 35 of the Set 2 | lorengau
# Processing Record 36 of the Set 2 | esperance
# Processing Record 37 of the Set 2 | puerto ayora
# Processing Record 38 of the Set 2 | fairbanks
# Processing Record 39 of the Set 2 | severobaykalsk
# Processing Record 40 of the Set 2 | awjilah
# Processing Record 41 of the Set 2 | saskylakh
# Processing Record 42 of the Set 2 | namibe
# Processing Record 43 of the Set 2 | piacabucu
# Processing Record 44 of the Set 2 | souillac
# Processing Record 45 of the Set 2 | broome
# Processing Record 46 of the Set 2 | san rafael
# Processing Record 47 of the Set 2 | rocha
# Processing Record 48 of the Set 2 | norman wells
# Processing Record 49 of the Set 2 | sao filipe
# Processing Record 50 of the Set 2 | mirnyy
# Processing Record 1 of the Set 3 | mar del plata
# Processing Record 2 of the Set 3 | khatanga
# Processing Record 3 of the Set 3 | vredendal
# Processing Record 4 of the Set 3 | bereda
# Processing Record 5 of the Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of the Set 3 | bambous virieux
# Processing Record 7 of the Set 3 | menongue
# Processing Record 8 of the Set 3 | provideniya
# Processing Record 9 of the Set 3 | la ronge
# Processing Record 10 of the Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of the Set 3 | abay
# Processing Record 12 of the Set 3 | daru
# Processing Record 13 of the Set 3 | antequera
# Processing Record 14 of the Set 3 | cockburn town
# Processing Record 15 of the Set 3 | jiddah
# City not found. Skipping...
# Processing Record 16 of the Set 3 | baykit
# Processing Record 17 of the Set 3 | badulla
# Processing Record 18 of the Set 3 | kenai
# Processing Record 19 of the Set 3 | kununurra
# Processing Record 20 of the Set 3 | flin flon
# Processing Record 21 of the Set 3 | gabriel leyva solano
# Processing Record 22 of the Set 3 | bluff
# Processing Record 23 of the Set 3 | roma
# Processing Record 24 of the Set 3 | vila
# Processing Record 25 of the Set 3 | tasiilaq
# Processing Record 26 of the Set 3 | puri
# Processing Record 27 of the Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of the Set 3 | keti bandar
# Processing Record 29 of the Set 3 | igrim
# Processing Record 30 of the Set 3 | yaan
# Processing Record 31 of the Set 3 | kurilsk
# Processing Record 32 of the Set 3 | da nang
# Processing Record 33 of the Set 3 | gerash
# Processing Record 34 of the Set 3 | pevek
# Processing Record 35 of the Set 3 | porto tolle
# Processing Record 36 of the Set 3 | paradwip
# City not found. Skipping...
# Processing Record 37 of the Set 3 | farafangana
# Processing Record 38 of the Set 3 | nara
# Processing Record 39 of the Set 3 | hemnes
# City not found. Skipping...
# Processing Record 40 of the Set 3 | shakawe
# Processing Record 41 of the Set 3 | miri
# Processing Record 42 of the Set 3 | namatanai
# Processing Record 43 of the Set 3 | hami
# Processing Record 44 of the Set 3 | shingu
# Processing Record 45 of the Set 3 | vila franca do campo
# Processing Record 46 of the Set 3 | new norfolk
# Processing Record 47 of the Set 3 | saint-francois
# Processing Record 48 of the Set 3 | portobelo
# Processing Record 49 of the Set 3 | havelock
# Processing Record 50 of the Set 3 | barrow
# Processing Record 1 of the Set 4 | chuy
# Processing Record 2 of the Set 4 | kavieng
# Processing Record 3 of the Set 4 | los llanos de aridane
# Processing Record 4 of the Set 4 | standerton
# Processing Record 5 of the Set 4 | nelson bay
# Processing Record 6 of the Set 4 | saleaula
# City not found. Skipping...
# Processing Record 7 of the Set 4 | nicoya
# Processing Record 8 of the Set 4 | xining
# Processing Record 9 of the Set 4 | hambantota
# Processing Record 10 of the Set 4 | hovd
# Processing Record 11 of the Set 4 | brae
# Processing Record 12 of the Set 4 | middle island
# Processing Record 13 of the Set 4 | lebu
# Processing Record 14 of the Set 4 | balikpapan
# Processing Record 15 of the Set 4 | baie-comeau
# Processing Record 16 of the Set 4 | terre-de-bas
# Processing Record 17 of the Set 4 | talnakh
# Processing Record 18 of the Set 4 | ahipara
# Processing Record 19 of the Set 4 | auki
# Processing Record 20 of the Set 4 | presidencia roque saenz pena
# Processing Record 21 of the Set 4 | loei
# Processing Record 22 of the Set 4 | kapit
# Processing Record 23 of the Set 4 | saint-augustin
# Processing Record 24 of the Set 4 | tidore
# City not found. Skipping...
# Processing Record 25 of the Set 4 | qaanaaq
# Processing Record 26 of the Set 4 | bilibino
# Processing Record 27 of the Set 4 | port lincoln
# Processing Record 28 of the Set 4 | novosokolniki
# Processing Record 29 of the Set 4 | kodiak
# Processing Record 30 of the Set 4 | rincon
# Processing Record 31 of the Set 4 | zinder
# Processing Record 32 of the Set 4 | bud
# Processing Record 33 of the Set 4 | bengkalis
# City not found. Skipping...
# Processing Record 34 of the Set 4 | progreso
# Processing Record 35 of the Set 4 | goderich
# Processing Record 36 of the Set 4 | dikson
# Processing Record 37 of the Set 4 | khonuu
# City not found. Skipping...
# Processing Record 38 of the Set 4 | barentu
# Processing Record 39 of the Set 4 | srednekolymsk
# Processing Record 40 of the Set 4 | teya
# Processing Record 41 of the Set 4 | college
# Processing Record 42 of the Set 4 | vostok
# Processing Record 43 of the Set 4 | moche
# Processing Record 44 of the Set 4 | takoradi
# Processing Record 45 of the Set 4 | yagoua
# Processing Record 46 of the Set 4 | pasighat
# Processing Record 47 of the Set 4 | constitucion
# Processing Record 48 of the Set 4 | vanavara
# Processing Record 49 of the Set 4 | iwanai
# Processing Record 50 of the Set 4 | salalah
# Processing Record 1 of the Set 5 | batemans bay
# Processing Record 2 of the Set 5 | praia
# Processing Record 3 of the Set 5 | chernyshevskiy
# Processing Record 4 of the Set 5 | pocone
# Processing Record 5 of the Set 5 | matay
# Processing Record 6 of the Set 5 | chokurdakh
# Processing Record 7 of the Set 5 | kautokeino
# Processing Record 8 of the Set 5 | castro
# Processing Record 9 of the Set 5 | anapolis
# Processing Record 10 of the Set 5 | chipiona
# Processing Record 11 of the Set 5 | sahibganj
# Processing Record 12 of the Set 5 | turka
# Processing Record 13 of the Set 5 | faanui
# Processing Record 14 of the Set 5 | nouadhibou
# Processing Record 15 of the Set 5 | abu samrah
# Processing Record 16 of the Set 5 | severo-kurilsk
# Processing Record 17 of the Set 5 | longyearbyen
# Processing Record 18 of the Set 5 | akcaabat
# Processing Record 19 of the Set 5 | rungata
# City not found. Skipping...
# Processing Record 20 of the Set 5 | sterling
# Processing Record 21 of the Set 5 | tak bai
# Processing Record 22 of the Set 5 | tuatapere
# Processing Record 23 of the Set 5 | mafinga
# Processing Record 24 of the Set 5 | general roca
# Processing Record 25 of the Set 5 | rio gallegos
# Processing Record 26 of the Set 5 | bonavista
# Processing Record 27 of the Set 5 | kaitangata
# Processing Record 28 of the Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of the Set 5 | capreol
# Processing Record 30 of the Set 5 | mount gambier
# Processing Record 31 of the Set 5 | jumla
# Processing Record 32 of the Set 5 | nouakchott
# Processing Record 33 of the Set 5 | arraial do cabo
# Processing Record 34 of the Set 5 | martan-chu
# Processing Record 35 of the Set 5 | coquimbo
# Processing Record 36 of the Set 5 | klaksvik
# Processing Record 37 of the Set 5 | carhuamayo
# Processing Record 38 of the Set 5 | hvide sande
# Processing Record 39 of the Set 5 | lufilufi
# Processing Record 40 of the Set 5 | ambilobe
# Processing Record 41 of the Set 5 | wamba
# Processing Record 42 of the Set 5 | doha
# Processing Record 43 of the Set 5 | andros town
# Processing Record 44 of the Set 5 | yulara
# Processing Record 45 of the Set 5 | weligama
# Processing Record 46 of the Set 5 | nabire
# Processing Record 47 of the Set 5 | victoria
# Processing Record 48 of the Set 5 | noumea
# Processing Record 49 of the Set 5 | letlhakane
# Processing Record 50 of the Set 5 | aloleng
# Processing Record 1 of the Set 6 | mackay
# Processing Record 2 of the Set 6 | ploemeur
# Processing Record 3 of the Set 6 | pandan
# Processing Record 4 of the Set 6 | nanortalik
# Processing Record 5 of the Set 6 | torbay
# Processing Record 6 of the Set 6 | aswan
# Processing Record 7 of the Set 6 | saint george
# Processing Record 8 of the Set 6 | ca mau
# Processing Record 9 of the Set 6 | port hawkesbury
# Processing Record 10 of the Set 6 | mocambique
# City not found. Skipping...
# Processing Record 11 of the Set 6 | novaya igirma
# Processing Record 12 of the Set 6 | demyansk
# Processing Record 13 of the Set 6 | kayseri
# Processing Record 14 of the Set 6 | broken hill
# Processing Record 15 of the Set 6 | dingle
# Processing Record 16 of the Set 6 | phan thiet
# Processing Record 17 of the Set 6 | thompson
# Processing Record 18 of the Set 6 | nerekhta
# Processing Record 19 of the Set 6 | vila velha
# Processing Record 20 of the Set 6 | bubaque
# Processing Record 21 of the Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of the Set 6 | fukue
# Processing Record 23 of the Set 6 | sona
# Processing Record 24 of the Set 6 | tual
# Processing Record 25 of the Set 6 | teguldet
# Processing Record 26 of the Set 6 | sinnamary
# Processing Record 27 of the Set 6 | okhotsk
# Processing Record 28 of the Set 6 | ust-koksa
# Processing Record 29 of the Set 6 | huarmey
# Processing Record 30 of the Set 6 | sitka
# Processing Record 31 of the Set 6 | desaguadero
# Processing Record 32 of the Set 6 | olafsvik
# Processing Record 33 of the Set 6 | cervo
# Processing Record 34 of the Set 6 | kanniyakumari
# Processing Record 35 of the Set 6 | san isidro
# Processing Record 36 of the Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of the Set 6 | tabialan
# City not found. Skipping...
# Processing Record 38 of the Set 6 | vardo
# Processing Record 39 of the Set 6 | bengkulu
# Processing Record 40 of the Set 6 | barra patuca
# Processing Record 41 of the Set 6 | khandyga
# Processing Record 42 of the Set 6 | youkounkoun
# Processing Record 43 of the Set 6 | buraydah
# Processing Record 44 of the Set 6 | foz
# Processing Record 45 of the Set 6 | meadow lake
# Processing Record 46 of the Set 6 | kushima
# Processing Record 47 of the Set 6 | amderma
# City not found. Skipping...
# Processing Record 48 of the Set 6 | manzhouli
# Processing Record 49 of the Set 6 | lata
# Processing Record 50 of the Set 6 | coihaique
# Processing Record 1 of the Set 7 | bucerias
# Processing Record 2 of the Set 7 | dali
# Processing Record 3 of the Set 7 | boende
# Processing Record 4 of the Set 7 | hasaki
# Processing Record 5 of the Set 7 | zhicheng
# Processing Record 6 of the Set 7 | saldanha
# Processing Record 7 of the Set 7 | uddevalla
# Processing Record 8 of the Set 7 | bathsheba
# Processing Record 9 of the Set 7 | saint-pierre
# Processing Record 10 of the Set 7 | puerto baquerizo moreno
# Processing Record 11 of the Set 7 | ponta do sol
# Processing Record 12 of the Set 7 | jining
# Processing Record 13 of the Set 7 | hervey bay
# Processing Record 14 of the Set 7 | mareeba
# Processing Record 15 of the Set 7 | sao felix do xingu
# Processing Record 16 of the Set 7 | cabo san lucas
# Processing Record 17 of the Set 7 | douglasville
# Processing Record 18 of the Set 7 | tiksi
# Processing Record 19 of the Set 7 | yomitan
# City not found. Skipping...
# Processing Record 20 of the Set 7 | suluq
# Processing Record 21 of the Set 7 | malwan
# City not found. Skipping...
# Processing Record 22 of the Set 7 | guerrero
# Processing Record 23 of the Set 7 | vasteras
# Processing Record 24 of the Set 7 | oyotun
# Processing Record 25 of the Set 7 | lafiagi
# Processing Record 26 of the Set 7 | spring valley
# Processing Record 27 of the Set 7 | cabras
# Processing Record 28 of the Set 7 | alexandria
# Processing Record 29 of the Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 30 of the Set 7 | joacaba
# Processing Record 31 of the Set 7 | ribeira grande
# Processing Record 32 of the Set 7 | aasmae
# City not found. Skipping...
# Processing Record 33 of the Set 7 | port hedland
# Processing Record 34 of the Set 7 | wakuya
# Processing Record 35 of the Set 7 | henties bay
# Processing Record 36 of the Set 7 | laguna
# Processing Record 37 of the Set 7 | nemuro
# Processing Record 38 of the Set 7 | madimba
# Processing Record 39 of the Set 7 | nome
# Processing Record 40 of the Set 7 | san cristobal
# Processing Record 41 of the Set 7 | lyuban
# Processing Record 42 of the Set 7 | praia da vitoria
# Processing Record 43 of the Set 7 | samusu
# City not found. Skipping...
# Processing Record 44 of the Set 7 | imeni zhelyabova
# Processing Record 45 of the Set 7 | cidreira
# Processing Record 46 of the Set 7 | bata
# Processing Record 47 of the Set 7 | ponferrada
# Processing Record 48 of the Set 7 | belmonte
# Processing Record 49 of the Set 7 | natchez
# Processing Record 50 of the Set 7 | eureka
# Processing Record 1 of the Set 8 | gat
# Processing Record 2 of the Set 8 | viligili
# City not found. Skipping...
# Processing Record 3 of the Set 8 | bonthe
# Processing Record 4 of the Set 8 | asau
# Processing Record 5 of the Set 8 | hitachi
# Processing Record 6 of the Set 8 | casas grandes
# Processing Record 7 of the Set 8 | princeton
# Processing Record 8 of the Set 8 | esik
# Processing Record 9 of the Set 8 | elizabeth city
# Processing Record 10 of the Set 8 | terney
# Processing Record 11 of the Set 8 | lasa
# Processing Record 12 of the Set 8 | kropotkin
# Processing Record 13 of the Set 8 | barawe
# City not found. Skipping...
# Processing Record 14 of the Set 8 | kavaratti
# Processing Record 15 of the Set 8 | santa maria
# Processing Record 16 of the Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 17 of the Set 8 | tamboril
# Processing Record 18 of the Set 8 | poum
# Processing Record 19 of the Set 8 | manicore
# Processing Record 20 of the Set 8 | guerrero negro
# Processing Record 21 of the Set 8 | kirakira
# Processing Record 22 of the Set 8 | lokosovo
# Processing Record 23 of the Set 8 | adrar
# Processing Record 24 of the Set 8 | maceio
# Processing Record 25 of the Set 8 | hede
# Processing Record 26 of the Set 8 | kalga
# Processing Record 27 of the Set 8 | bethanien
# Processing Record 28 of the Set 8 | taihe
# Processing Record 29 of the Set 8 | taua
# Processing Record 30 of the Set 8 | samarai
# Processing Record 31 of the Set 8 | sao joao da barra
# Processing Record 32 of the Set 8 | umm kaddadah
# Processing Record 33 of the Set 8 | tarudant
# City not found. Skipping...
# Processing Record 34 of the Set 8 | nisia floresta
# Processing Record 35 of the Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of the Set 8 | abakaliki
# Processing Record 37 of the Set 8 | dekoa
# City not found. Skipping...
# Processing Record 38 of the Set 8 | raudeberg
# Processing Record 39 of the Set 8 | itacare
# Processing Record 40 of the Set 8 | kieta
# Processing Record 41 of the Set 8 | neuquen
# Processing Record 42 of the Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 43 of the Set 8 | smolenka
# Processing Record 44 of the Set 8 | rio grande
# Processing Record 45 of the Set 8 | shizunai
# Processing Record 46 of the Set 8 | raozan
# City not found. Skipping...
# Processing Record 47 of the Set 8 | scottsbluff
# Processing Record 48 of the Set 8 | concarneau
# Processing Record 49 of the Set 8 | portoferraio
# Processing Record 50 of the Set 8 | chunoyar
# Processing Record 1 of the Set 9 | santiago de cao
# Processing Record 2 of the Set 9 | lindon
# Processing Record 3 of the Set 9 | eau claire
# Processing Record 4 of the Set 9 | ugoofaaru
# Processing Record 5 of the Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of the Set 9 | marcona
# City not found. Skipping...
# Processing Record 7 of the Set 9 | beira
# Processing Record 8 of the Set 9 | murgab
# Processing Record 9 of the Set 9 | miandrivazo
# Processing Record 10 of the Set 9 | naze
# Processing Record 11 of the Set 9 | aklavik
# Processing Record 12 of the Set 9 | safranbolu
# Processing Record 13 of the Set 9 | urumqi
# Processing Record 14 of the Set 9 | tallahassee
# Processing Record 15 of the Set 9 | sengiley
# Processing Record 16 of the Set 9 | eugene
# Processing Record 17 of the Set 9 | bodden town
# Processing Record 18 of the Set 9 | lyngseidet
# Processing Record 19 of the Set 9 | taoudenni
# Processing Record 20 of the Set 9 | chardara
# Processing Record 21 of the Set 9 | morondava
# Processing Record 22 of the Set 9 | acapulco
# Processing Record 23 of the Set 9 | camacha
# Processing Record 24 of the Set 9 | bedele
# Processing Record 25 of the Set 9 | uchiza
# Processing Record 26 of the Set 9 | lamu
# Processing Record 27 of the Set 9 | ulaangom
# Processing Record 28 of the Set 9 | codrington
# Processing Record 29 of the Set 9 | blonduos
# City not found. Skipping...
# Processing Record 30 of the Set 9 | maykain
# City not found. Skipping...
# Processing Record 31 of the Set 9 | fortuna
# Processing Record 32 of the Set 9 | ardmore
# Processing Record 33 of the Set 9 | isangel
# Processing Record 34 of the Set 9 | lubango
# Processing Record 35 of the Set 9 | hazorasp
# Processing Record 36 of the Set 9 | tula
# Processing Record 37 of the Set 9 | antofagasta
# Processing Record 38 of the Set 9 | jinchang
# Processing Record 39 of the Set 9 | barbar
# City not found. Skipping...
# Processing Record 40 of the Set 9 | half moon bay
# Processing Record 41 of the Set 9 | baruun-urt
# Processing Record 42 of the Set 9 | grand centre
# City not found. Skipping...
# Processing Record 43 of the Set 9 | ginir
# Processing Record 44 of the Set 9 | desnogorsk
# Processing Record 45 of the Set 9 | warqla
# City not found. Skipping...
# Processing Record 46 of the Set 9 | taksimo
# Processing Record 47 of the Set 9 | port keats
# Processing Record 48 of the Set 9 | kyra
# Processing Record 49 of the Set 9 | temaraia
# City not found. Skipping...
# Processing Record 50 of the Set 9 | sola
# Processing Record 1 of the Set 10 | anadyr
# Processing Record 2 of the Set 10 | shache
# Processing Record 3 of the Set 10 | cinco esquinas
# Processing Record 4 of the Set 10 | mount isa
# Processing Record 5 of the Set 10 | dunedin
# Processing Record 6 of the Set 10 | jacareacanga
# Processing Record 7 of the Set 10 | novobirilyussy
# Processing Record 8 of the Set 10 | aripuana
# Processing Record 9 of the Set 10 | idrinskoye
# Processing Record 10 of the Set 10 | burnie
# Processing Record 11 of the Set 10 | nanzhang
# Processing Record 12 of the Set 10 | te anau
# Processing Record 13 of the Set 10 | odweyne
# Processing Record 14 of the Set 10 | kalmunai
# Processing Record 15 of the Set 10 | xiongshi
# City not found. Skipping...
# Processing Record 16 of the Set 10 | katsuura
# Processing Record 17 of the Set 10 | mizdah
# Processing Record 18 of the Set 10 | micheweni
# Processing Record 19 of the Set 10 | acarau
# Processing Record 20 of the Set 10 | margate
# Processing Record 21 of the Set 10 | balykshi
# Processing Record 22 of the Set 10 | radzyn podlaski
# Processing Record 23 of the Set 10 | nola
# Processing Record 24 of the Set 10 | nienburg
# Processing Record 25 of the Set 10 | yelnya
# Processing Record 26 of the Set 10 | zharkent
# Processing Record 27 of the Set 10 | agapovka
# Processing Record 28 of the Set 10 | fare
# Processing Record 29 of the Set 10 | ware
# Processing Record 30 of the Set 10 | sheridan
# Processing Record 31 of the Set 10 | necochea
# Processing Record 32 of the Set 10 | macau
# Processing Record 33 of the Set 10 | sept-iles
# Processing Record 34 of the Set 10 | mantua
# Processing Record 35 of the Set 10 | xai-xai
# Processing Record 36 of the Set 10 | sembe
# Processing Record 37 of the Set 10 | kutum
# Processing Record 38 of the Set 10 | yar-sale
# Processing Record 39 of the Set 10 | russell
# Processing Record 40 of the Set 10 | cabedelo
# Processing Record 41 of the Set 10 | harper
# Processing Record 42 of the Set 10 | mayor pablo lagerenza
# Processing Record 43 of the Set 10 | san ramon de la nueva oran
# Processing Record 44 of the Set 10 | luanda
# Processing Record 45 of the Set 10 | bykovo
# Processing Record 46 of the Set 10 | maskinonge
# Processing Record 47 of the Set 10 | qui nhon
# Processing Record 48 of the Set 10 | trincomalee
# Processing Record 49 of the Set 10 | rio branco
# Processing Record 50 of the Set 10 | zhangye
# Processing Record 1 of the Set 11 | goundam
# Processing Record 2 of the Set 11 | saint cloud
# Processing Record 3 of the Set 11 | phonhong
# Processing Record 4 of the Set 11 | port blair
# Processing Record 5 of the Set 11 | lucapa
# Processing Record 6 of the Set 11 | kasangulu
# Processing Record 7 of the Set 11 | soledade
# Processing Record 8 of the Set 11 | constantine
# Processing Record 9 of the Set 11 | kungurtug
# Processing Record 10 of the Set 11 | mabaruma
# Processing Record 11 of the Set 11 | hokitika
# Processing Record 12 of the Set 11 | krasnoselkup
# Processing Record 13 of the Set 11 | slavyanka
# Processing Record 14 of the Set 11 | moses lake
# Processing Record 15 of the Set 11 | kuytun
# Processing Record 16 of the Set 11 | clarksburg
# Processing Record 17 of the Set 11 | mbinga
# Processing Record 18 of the Set 11 | seagoville
# Processing Record 19 of the Set 11 | lolua
# City not found. Skipping...
# Processing Record 20 of the Set 11 | tyrma
# Processing Record 21 of the Set 11 | jiujiang
# Processing Record 22 of the Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 23 of the Set 11 | dudinka
# Processing Record 24 of the Set 11 | asfi
# Processing Record 25 of the Set 11 | semirom
# Processing Record 26 of the Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 27 of the Set 11 | kualakapuas
# Processing Record 28 of the Set 11 | gimli
# Processing Record 29 of the Set 11 | teknaf
# Processing Record 30 of the Set 11 | tautira
# Processing Record 31 of the Set 11 | chalons-en-champagne
# Processing Record 32 of the Set 11 | kruisfontein
# Processing Record 33 of the Set 11 | hayato
# City not found. Skipping...
# Processing Record 34 of the Set 11 | palmer
# Processing Record 35 of the Set 11 | kitimat
# Processing Record 36 of the Set 11 | muros
# Processing Record 37 of the Set 11 | christchurch
# Processing Record 38 of the Set 11 | bunia
# Processing Record 39 of the Set 11 | gushikawa
# Processing Record 40 of the Set 11 | mayo
# Processing Record 41 of the Set 11 | vyartsilya
# Processing Record 42 of the Set 11 | kaeo
# Processing Record 43 of the Set 11 | sampit
# Processing Record 44 of the Set 11 | nortelandia
# Processing Record 45 of the Set 11 | bongandanga
# Processing Record 46 of the Set 11 | cherskiy
# Processing Record 47 of the Set 11 | hofn
# Processing Record 48 of the Set 11 | lukovetskiy
# Processing Record 49 of the Set 11 | usinsk
# Processing Record 50 of the Set 11 | damghan
# Processing Record 1 of the Set 12 | oranjemund
# Processing Record 2 of the Set 12 | stepnogorsk
# Processing Record 3 of the Set 12 | caravelas
# Processing Record 4 of the Set 12 | honningsvag
# Processing Record 5 of the Set 12 | ancud
# Processing Record 6 of the Set 12 | chapais
# Processing Record 7 of the Set 12 | meyungs
# City not found. Skipping...
# Processing Record 8 of the Set 12 | ucluelet
# Processing Record 9 of the Set 12 | effingham
# Processing Record 10 of the Set 12 | tevaitoa
# Processing Record 11 of the Set 12 | nizhniy kuranakh
# Processing Record 12 of the Set 12 | narowal
# Processing Record 13 of the Set 12 | colon
# Processing Record 14 of the Set 12 | lerwick
# Processing Record 15 of the Set 12 | mandera
# Processing Record 16 of the Set 12 | yeppoon
# Processing Record 17 of the Set 12 | itarema
# Processing Record 18 of the Set 12 | port shepstone
# Processing Record 19 of the Set 12 | novobiryusinskiy
# Processing Record 20 of the Set 12 | korla
# Processing Record 21 of the Set 12 | dhemaji
# Processing Record 22 of the Set 12 | dublin
# Processing Record 23 of the Set 12 | lavrentiya
# Processing Record 24 of the Set 12 | bahia honda
# Processing Record 25 of the Set 12 | santa rosa
# Processing Record 26 of the Set 12 | vestmanna
# Processing Record 27 of the Set 12 | tromso
# Processing Record 28 of the Set 12 | khor
# Processing Record 29 of the Set 12 | sekoma
# Processing Record 30 of the Set 12 | ayagoz
# Processing Record 31 of the Set 12 | novyy urengoy
# Processing Record 32 of the Set 12 | moron
# Processing Record 33 of the Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 34 of the Set 12 | antsohihy
# Processing Record 35 of the Set 12 | rodeo
# Processing Record 36 of the Set 12 | iqaluit
# Processing Record 37 of the Set 12 | strezhevoy
# Processing Record 38 of the Set 12 | baghdad
# Processing Record 39 of the Set 12 | pine bluff
# Processing Record 40 of the Set 12 | pyu
# Processing Record 41 of the Set 12 | wampusirpi
# City not found. Skipping...
# Processing Record 42 of the Set 12 | tres de maio
# Processing Record 43 of the Set 12 | salta
# Processing Record 44 of the Set 12 | nassau
# Processing Record 45 of the Set 12 | egvekinot
# Processing Record 46 of the Set 12 | kampong cham
# Processing Record 47 of the Set 12 | maragogi
# Processing Record 48 of the Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of the Set 12 | sao gabriel
# Processing Record 50 of the Set 12 | puerto leguizamo
# Processing Record 1 of the Set 13 | pudozh
# Processing Record 2 of the Set 13 | chumikan
# Processing Record 3 of the Set 13 | coxquihui
# Processing Record 4 of the Set 13 | dolores
# Processing Record 5 of the Set 13 | horodok
# Processing Record 6 of the Set 13 | canete
# Processing Record 7 of the Set 13 | keetmanshoop
# Processing Record 8 of the Set 13 | salym
# Processing Record 9 of the Set 13 | jaru
# Processing Record 10 of the Set 13 | hualmay
# Processing Record 11 of the Set 13 | launceston
# Processing Record 12 of the Set 13 | minsk mazowiecki
# Processing Record 13 of the Set 13 | cuenca
# Processing Record 14 of the Set 13 | prince albert
# Processing Record 15 of the Set 13 | banjar
# Processing Record 16 of the Set 13 | mundo nuevo
# Processing Record 17 of the Set 13 | penzance
# Processing Record 18 of the Set 13 | tilichiki
# Processing Record 19 of the Set 13 | zeya
# Processing Record 20 of the Set 13 | ilulissat
# Processing Record 21 of the Set 13 | tocopilla
# Processing Record 22 of the Set 13 | ipora
# Processing Record 23 of the Set 13 | fernandopolis
# Processing Record 24 of the Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 25 of the Set 13 | tura
# Processing Record 26 of the Set 13 | bonnyville
# Processing Record 27 of the Set 13 | aguai
# Processing Record 28 of the Set 13 | port hueneme
# Processing Record 29 of the Set 13 | hamilton
# Processing Record 30 of the Set 13 | basar
# Processing Record 31 of the Set 13 | byron bay
# Processing Record 32 of the Set 13 | joue-les-tours
# Processing Record 33 of the Set 13 | araguaina
# Processing Record 34 of the Set 13 | chanika
# Processing Record 35 of the Set 13 | coolum beach
# Processing Record 36 of the Set 13 | pisco
# Processing Record 37 of the Set 13 | margherita
# Processing Record 38 of the Set 13 | tosya
# Processing Record 39 of the Set 13 | benguela
# Processing Record 40 of the Set 13 | shipunovo
# Processing Record 41 of the Set 13 | ruzhyn
# Processing Record 42 of the Set 13 | utiroa
# City not found. Skipping...
# Processing Record 43 of the Set 13 | faya
# Processing Record 44 of the Set 13 | marystown
# Processing Record 45 of the Set 13 | koungou
# Processing Record 46 of the Set 13 | payo
# Processing Record 47 of the Set 13 | bisho
# Processing Record 48 of the Set 13 | vallenar
# Processing Record 49 of the Set 13 | ahtopol
# Processing Record 50 of the Set 13 | safaga
# Processing Record 1 of the Set 14 | muroto
# Processing Record 2 of the Set 14 | ketchikan
# Processing Record 3 of the Set 14 | rostaq
# City not found. Skipping...
# Processing Record 4 of the Set 14 | san fernando
# Processing Record 5 of the Set 14 | sistranda
# Processing Record 6 of the Set 14 | touros
# Processing Record 7 of the Set 14 | abha
# Processing Record 8 of the Set 14 | kahului
# Processing Record 9 of the Set 14 | kuala kedah
# Processing Record 10 of the Set 14 | limoges
# Processing Record 11 of the Set 14 | mulege
# Processing Record 12 of the Set 14 | nazarovo
# Processing Record 13 of the Set 14 | zhezkazgan
# Processing Record 14 of the Set 14 | de-kastri
# Processing Record 15 of the Set 14 | pimenta bueno
# Processing Record 16 of the Set 14 | ostrovnoy
# Processing Record 17 of the Set 14 | yushan
# Processing Record 18 of the Set 14 | zhangjiakou
# Processing Record 19 of the Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 20 of the Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 21 of the Set 14 | manggar
# Processing Record 22 of the Set 14 | maniitsoq
# Processing Record 23 of the Set 14 | san luis
# Processing Record 24 of the Set 14 | kemijarvi
# Processing Record 25 of the Set 14 | luderitz
# Processing Record 26 of the Set 14 | watertown
# Processing Record 27 of the Set 14 | maneadero
# Processing Record 28 of the Set 14 | emerald
# Processing Record 29 of the Set 14 | nalut
# Processing Record 30 of the Set 14 | sabang
# Processing Record 31 of the Set 14 | omsukchan
# Processing Record 32 of the Set 14 | toledo
# Processing Record 33 of the Set 14 | nantucket
# Processing Record 34 of the Set 14 | kumla
# Processing Record 35 of the Set 14 | sabha
# Processing Record 36 of the Set 14 | ennis
# Processing Record 37 of the Set 14 | karangampel
# Processing Record 38 of the Set 14 | itapora
# Processing Record 39 of the Set 14 | conceicao do araguaia
# Processing Record 40 of the Set 14 | campo verde
# Processing Record 41 of the Set 14 | amapa
# Processing Record 42 of the Set 14 | bobrovytsya
# Processing Record 43 of the Set 14 | tezu
# Processing Record 44 of the Set 14 | buchanan
# Processing Record 45 of the Set 14 | san jose del palmar
# Processing Record 46 of the Set 14 | valmiera
# Processing Record 47 of the Set 14 | boguchany
# Processing Record 48 of the Set 14 | kamaishi
# Processing Record 49 of the Set 14 | vilhena
# Processing Record 50 of the Set 14 | sorvag
# City not found. Skipping...
# Processing Record 1 of the Set 15 | ocos
# Processing Record 2 of the Set 15 | khovu-aksy
# Processing Record 3 of the Set 15 | ust-omchug
# Processing Record 4 of the Set 15 | aasiaat
# Processing Record 5 of the Set 15 | statesboro
# Processing Record 6 of the Set 15 | zhanaozen
# Processing Record 7 of the Set 15 | ayer itam
# City not found. Skipping...
# Processing Record 8 of the Set 15 | pathein
# Processing Record 9 of the Set 15 | richards bay
# Processing Record 10 of the Set 15 | mwinilunga
# Processing Record 11 of the Set 15 | xuddur
# Processing Record 12 of the Set 15 | winslow
# Processing Record 13 of the Set 15 | turbat
# Processing Record 14 of the Set 15 | burgeo
# Processing Record 15 of the Set 15 | aykhal
# Processing Record 16 of the Set 15 | ojinaga
# Processing Record 17 of the Set 15 | marihatag
# Processing Record 18 of the Set 15 | vokhtoga
# Processing Record 19 of the Set 15 | dondo
# Processing Record 20 of the Set 15 | mehamn
# Processing Record 21 of the Set 15 | kamyshin
# Processing Record 22 of the Set 15 | sataua
# City not found. Skipping...
# Processing Record 23 of the Set 15 | kota kinabalu
# Processing Record 24 of the Set 15 | vitim
# Processing Record 25 of the Set 15 | mamurras
# Processing Record 26 of the Set 15 | staicele
# Processing Record 27 of the Set 15 | yatou
# Processing Record 28 of the Set 15 | qaqortoq
# Processing Record 29 of the Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of the Set 15 | darovskoy
# Processing Record 31 of the Set 15 | abapo
# Processing Record 32 of the Set 15 | dakar
# Processing Record 33 of the Set 15 | shushtar
# Processing Record 34 of the Set 15 | hope
# Processing Record 35 of the Set 15 | ust-kuyga
# Processing Record 36 of the Set 15 | marfino
# Processing Record 37 of the Set 15 | nguiu
# City not found. Skipping...
# Processing Record 38 of the Set 15 | falesti
# Processing Record 39 of the Set 15 | elkhart
# Processing Record 40 of the Set 15 | vydrino
# Processing Record 41 of the Set 15 | chicama
# Processing Record 42 of the Set 15 | bristol
# Processing Record 43 of the Set 15 | vreed en hoop
# City not found. Skipping...
# Processing Record 44 of the Set 15 | rancho palos verdes
# Processing Record 45 of the Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 46 of the Set 15 | xghajra
# City not found. Skipping...
# Processing Record 47 of the Set 15 | tabug
# Processing Record 48 of the Set 15 | new delhi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 681

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Karratha      AU -20.7377  116.8463     93.63        39          57
# 1      Oussouye      SN  12.4850  -16.5469     71.78        60          72
# 2  Punta Arenas      CL -53.1500  -70.9167     48.31        61          75
# 3        Narsaq      GL  60.9167  -46.0500     18.59        75         100
# 4     Geraldton      AU -28.7667  114.6000     80.13        65           0
#
#    Wind Speed Current Description
# 0       12.28       broken clouds
# 1       10.85       broken clouds
# 2       29.93       broken clouds
# 3       18.68                snow
# 4       14.97           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
